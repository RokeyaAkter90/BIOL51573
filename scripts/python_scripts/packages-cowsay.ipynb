# %%
import cowsay

# %%
# get list of possible character
# format is:module.function
cowsay.char_names
# Out:
# ['beavis',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'fox',
#  'ghostbusters',
#  'kitty',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
#cowsay.ghostbusters('Hell, World!')
#cowsay.cow('Hell, World!')
cowsay.beavis('Hell, World!')
# Out:
#   ____________
# | Hell, World! |
# ...
#                  \
#                   \
#                    \
#                          _------~~-,
#                       ,'            ,
#                       /               \\
#                      /                :
#                     |                  '
#                     |                  |
#                     |                  |
#                      |   _--           |
#                      _| =-.     .-.   ||
#                      o|/o/       _.   |
#                      /  ~          \\ |
#                    (____\@)  ___~    |
#                       |_===~~~.`    |
#                    _______.--~     |
#                    \\________       |
#                             \\      |
#                           __/-___-- -__
#                          /            _ \\
